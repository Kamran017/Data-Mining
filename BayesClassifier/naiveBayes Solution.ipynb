# %% [markdown]
# <div id="about_dataset">
#     <h2>About the dataset</h2>
# </div>

# %% [markdown]
# Imagine a telecommunications provider has segmented its customer base by service usage patterns, categorizing the customers into four groups. If demographic data can be used to predict group membership, the company can customize offers for individual prospective customers. It is a classification problem. That is, given the dataset,  with predefined labels, we need to build a model to be used to predict class of a new or unknown case.
#
# The example focuses on using demographic data, such as region, age, and marital, to predict usage patterns.
#
# The target field, called **custcat**, has four possible values that correspond to the four customer groups, as follows:
#
#   1- Basic Service
#
#   2- E-Service
#
#   3- Plus Service
#
#   4- Total Service
#
#
# Our objective is to build a classifier, to predict the class of unknown cases.

# %% [markdown]
# ### Import Libraries

# %%
#import libraries for mathematical operations and importing dataset
import pandas as pd
import numpy as np

# %% [markdown]
# ### Import dataset

# %%
#import dataset
dataFrame=pd.read_csv('teleCust1000t.csv')
#show first 5 elements of dataset
dataFrame.head()
#get mean and standard  deviation of needful properties in order to use it in gaussian function
mean = dataFrame[['tenure', 'age', 'income', 'employ', 'custcat']].groupby('custcat').mean()
standartDeviation = dataFrame[['tenure', 'age', 'income', 'employ', 'custcat']].groupby('custcat').std()
#convert mean and standard  deviation values to list
meanArray = mean.values.tolist()
stdArray = standartDeviation.values.tolist()

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split
#get values from dataframe in order to split dataset
X = dataFrame[['tenure','age','income','employ']] .values 
Y = dataFrame['custcat'].values
#split dataset 
X_train, X_test, Y_train, Y_test=train_test_split(X, Y, test_size=0.2, random_state=42)

#get unique numbers from Ytrain and their counts
uniqueNumbers, count =np.unique(Y_train, return_counts=True)
#concatenate lists in one dictionary with uniqie class numbers and their counts
custcastDic= dict(zip(uniqueNumbers, count))

#print dictionary
custcastDic
# Out:
# {1: 209, 2: 175, 3: 219, 4: 197}

# %% [markdown]
# ### Classification and Probability Calculation

# %%
#gaussian distribution function
def gaussFunc(x, std, mean):
    return 1/(std * np.sqrt(2 * np.pi)) * np.exp( - (x - mean)**2 / (2 * std**2) ) 

#calculate probability with formula
def calculateProbability(X_test, custcastDict):
    maxProbValue = 0
    index = 0
    #iterate over 4 classes
    for i in range(0,4):
        result_1 = gaussFunc(X_test[0] ,stdArray[i][0], meanArray[i][0]) * gaussFunc(X_test[1] ,stdArray[i][1], meanArray[i][1]) * gaussFunc(X_test[2] ,stdArray[i][2], meanArray[i][2]) * gaussFunc(X_test[3] ,stdArray[i][3], meanArray[i][3])
        
        result =(custcastDic[i+1] /800) * result_1 #custcast dict has 800 property
        #find maximum probability value
        if result > maxProbValue:
            index = i
            maxProbValue = result
    return index + 1

#finally calculate probability and accuracy value
def result(X_test, Y_test):
    total = 0
    for i in range(200):
        v = calculateProbability(X_test[i], custcastDic)
        print("\nX test value : " ,X_test[i])
        print("Predicted value : "  , v )
        print("Real test value:  ", Y_test[i])
        
        #calculate accuracy value
        if v == Y_test[i]:
            total += 1
            print("Prediction is successfull")
        elif v != Y_test[i]:
            print("Prediction is unsuccessfull")
        print("\n")
        
        
    print("----------------------------------\n")
    print("      Accuracy value: " + str(total/2))
    print("\n----------------------------------")

result(X_test, Y_test)
# Out:
# X test value :  [33. 33. 42.  7.]
# Predicted value :  1
# Real test value:   2
# Prediction is unsuccessfull
#
#
#
# X test value :  [ 5. 31. 34.  9.]
# Predicted value :  1
# Real test value:   3
# Prediction is unsuccessfull
#
#
#
# X test value :  [55. 45. 36.  9.]
# Predicted value :  2
# Real test value:   3
# Prediction is unsuccessfull
#
#
#
# X test value :  [49. 37. 50. 12.]
# Predicted value :  1
# Real test value:   2
# Prediction is unsuccessfull
#
#
#
# X test value :  [66. 55. 80. 24.]
# Predicted value :  3
# Real test value:   3
# Prediction is successfull
#
#
#
# X test value :  [19. 29. 18.  2.]
# Predicted value :  1
# Real test value:   1
# Prediction is successfull
#
#
#
# X test value :  [ 4. 37. 41.  8.]
# Predicted value :  1
# Real test value:   1
# Prediction is successfull
#
#
#
# X test value :  [55. 44. 68. 15.]
# Predicted value :  2
# Real test value:   3
# Prediction is unsuccessfull
#
#
#
# X test value :  [34. 23. 24.  7.]
# Predicted value :  1
# Real test value:   3
# Prediction is unsuccessfull
#
#
#
# X test value :  [20. 25. 33.  0.]
# Predicted value :  1
# Real test value:   1
# Prediction is successfull
#
#
#
# X test value :  [17. 42. 31.  2.]
# Predicted value :  1
# Real test value:   4
# Prediction is unsuccessfull
#
#
#
# X test value :  [ 4. 22. 22.  2.]
# Predicted value :  1
# Real test value:   3
# Prediction is unsuccessfull
#
#
#
# X test value :  [39. 51. 41. 20.]
# Predicted value :  3
# Real test value:   4
# Prediction is unsuccessfull
#
#
#
# X test value :  [70. 44. 87. 18.]
# Predicted value :  3
# Real test value:   3
# Prediction is successfull
#
#
#
# X test value :  [27. 67. 33. 19.]
# Predicted value :  3
# Real test value:   3
# Prediction is successfull
#
#
#
# X test value :  [ 28.  38. 119.   2.]
# Predicted value :  1
# Real test value:   4
# Prediction is unsuccessfull
#
#
#
# X test value :  [22. 51. 49.  1.]
# Predicted value :  1
# Real test value:   1
# Prediction is successfull
#
#
#
# X test value :  [
]
# Predicted value :  1
# Real test value:   2
# Prediction is unsuccessfull
#
#
#
# X test value :  [ 8. 22. 25.  0.]
# Predicted value :  1
# Real test value:   3
# Prediction is unsuccessfull
#
#
#
# X test value :  [65. 37. 56. 15.]
# Predicted value :  2
# Real test value:   2
# Prediction is successfull
#
#
#
# X test value :  [15. 35. 34.  8.]
# Predicted value :  1
# Real test value:   2
# Prediction is unsuccessfull
#
#
#
# X test value :  [48. 42. 46.  4.]
# Predicted value :  1
# Real test value:   3
# Prediction is unsuccessfull
#
#
#
# X test value :  [62. 35. 28.  8.]
# Predicted value :  2
# Real test value:   2
# Prediction is successfull
#
#
#
# X test value :  [40. 29. 40.  8.]
# Predicted value :  1
# Real test value:   3
# Prediction is unsuccessfull
#
#
#
# X test value :  [13. 33. 38. 10.]
# Predicted value :  1
# Real test value:   4
# Prediction is unsuccessfull
#
#
#
# X test value :  [16. 35. 46.  3.]
# Predicted value :  1
# Real test value:   1
# Prediction is successfull
#
#
#
# X test value :  [ 26.  39. 105.  13.]
# Predicted value :  1
# Real test value:   4
# Prediction is unsuccessfull
#
#
#
# X test value :  [60. 55. 67. 18.]
# Predicted value :  3
# Real test value:   1
# Prediction is unsuccessfull
#
#
#
# X test value :  [46. 31. 21.  5.]
# Predicted value :  1
# Real test value:   3
# Prediction is unsuccessfull
#
#
#
# X test value :  [24. 40. 39.  5.]
# Predicted value :  1
# Real test value:   3
# Prediction is unsuccessfull
#
#
#
# X test value :  [29. 26. 34.  7.]
# Predicted value :  1
# Real test value:   3
# Prediction is unsuccessfull
#
#
#
# X test value :  [72. 69. 17. 36.]
# Predicted value :  3
# Real test value:   2
# Prediction is unsuccessfull
#
#
#
# X test value :  [51. 38. 51. 18.]
# Predicted value :  3
# Real test value:   3
# Prediction is successfull
#
#
#
# X test value :  [ 67.  52. 248.  20.]
# Predicted value :  3
# Real test value:   3
# Prediction is successfull
#
#
#
# X test value :  [42. 36. 86. 15.]
# Predicted value :  1
# Real test value:   2
# Prediction is unsuccessfull
#
#
#
# X test value :  [30. 23. 19.  1.]
# Predicted value :  1
# Real test value:   2
# Prediction is unsuccessfull
#
#
#
# X test value :  [10. 27. 15.  2.]
# Predicted value :  1
# Real test value:   4
# Prediction is unsuccessfull
#
#
#
# X test value :  [  8.  42. 129.  17.]
# Predicted value :  1
# Real test value:   1
# Prediction is successfull
#
#
#
# X test value :  [ 7. 24. 29.  3.]
# Predicted value :  1
# Real test value:   1
# Prediction is successfull
#
#
#
# X test value :  [35. 61. 41. 11.]
# Predicted value :  1
# Real test value:   1
# Prediction is successfull
#
#
#
# X test value :  [ 53.  33. 101.   4.]
# Predicted value :  4
# Real test value:   4
# Prediction is successfull
#
#
#
# X test value :  [33. 33. 53. 14.]
# Predicted value :  1
# Real test value:   1
# Prediction is successfull
#
#
#
# X test value :  [72. 61. 61.  8.]
# Predicted value :  3
# Real test value:   2
# Prediction is unsuccessfull
#
#
#
# X test value :  [ 42.  57. 209.  40.]
# Predicted value :  3
# Real test value:   1
# Prediction is unsuccessfull
#
#
#
# X test value :  [69. 42. 19.  0.]
# Predicted value :  2
# Real test value:   1
# Prediction is unsuccessfull
#
#
#
# X test value :  [ 7. 34. 22.  5.]
# Predicted value :  1
# Real test value:   1
# Prediction is successfull
#
#
#
# X test value :  [27. 28. 58.  0.]
# Predicted value :  1
# Real test value:   3
# Prediction is unsuccessfull
#
#
#
# X test value :  [23. 31. 45.  0.]
# Predicted value :  1
# Real test value:   2
# Prediction is unsuccessfull
#
#
#
# X test value :  [41. 44. 59. 21.]
# Predicted value :  3
# Real test value:   2
# Prediction is unsuccessfull
#
#
#
# X test value :  [ 46.  48. 256.  25.]
# Predicted value :  3
# Real test value:   4
# Prediction is unsuccessfull
#
#
#
# X test value :  [ 3. 31. 23.  4.]
# Predicted value :  1
# Real test value:   4
# Prediction is unsuccessfull
#
#
#
# X test value :  [42. 48. 27.  5.]
# Predicted value :  1
# Real test value:   4
# Prediction is unsuccessfull
#
#
#
# X test value :  [58. 36. 38. 14.]
# Predicted value :  2
# Real test value:   2
# Prediction is successfull
#
#
#
# X test value :  [28. 36. 69.  2.]
# Predicted value :  1
# Real test value:   4
# Prediction is unsuccessfull
#
#
#
# X test value :  [ 51.  49. 203.  27.]
# Predicted value :  3
# Real test value:   3
# Prediction is successfull
#
#
#
# X test value :  [37. 51. 54. 15.]
# Predicted value :  1
# Real test value:   3
# Prediction is unsuccessfull
#
#
#
# X test value :  [ 72.  54. 345.  32.]
# Predicted value :  3
# Real test value:   3
# Prediction is successfull
#
#
#
# X test value :  [ 65.  70. 115.  39.]
# Predicted value :  3
# Real test value:   4
# Prediction is unsuccessfull
#
#
#
# X test value :  [ 7. 43. 69.  5.]
# Predicted value :  1
# Real test value:   1
# Prediction is successfull
#
#
#
# X test value :  [56. 42. 24.  5.]
# Predicted value :  2
# Real test value:   3
# Prediction is unsuccessfull
#
#
#
# X test value :  [52. 42. 27.  8.]
# Predicted value :  1
# Real test value:   3
# Prediction is unsuccessfull
#
#
#
# X test value :  [ 8. 42. 66. 10.]
# Predicted value :  1
# Real test value:   4
# Prediction is unsuccessfull
#
#
#
# X test value :  [36. 48. 29.  2.]
# Predicted value :  1
# Real test value:   1
# Prediction is successfull
#
#
#
# X test value :  [ 5. 44. 83. 16.]
# Predicted value :  1
# Real test value:   2
# Prediction is unsuccessfull
#
#
#
# X test value :  [ 7. 40. 33.  2.]
# Predicted value :  1
# Real test value:   1
# Prediction is successfull
#
#
#
# X test value :  [ 3. 32. 58. 11.]
# Predicted value :  1
# Real test value:   4
# Prediction is unsuccessfull
#
#
#
# X test value :  [ 43.  36. 107.  19.]
# Predicted value :  3
# Real test value:   2
# Prediction is unsuccessfull
#
#
#
# X test value :  [20. 48. 45.  2.]
# Predicted value :  1
# Real test value:   3
# Prediction is unsuccessfull
#
#
#
# X test value :  [20. 42. 17.  5.]
# Predicted value :  1
# Real test value:   1
# Prediction is successfull
#
#
#
# X test value :  [28. 29. 23.  5.]
# Predicted value :  1
# Real test value:   2
# Prediction is unsuccessfull
#
#
#
# X test value :  [ 50.  54. 248.  28.]
# Predicted value :  3
# Real test value:   3
# Prediction is successfull
#
#
#
# X test value :  [25. 20. 15.  0.]
# Predicted value :  1
# Real test value:   3
# Prediction is unsuccessfull
#
#
#
# X test value :  [ 37.  42. 115.  22.]
# Predicted value :  3
# Real test value:   3
# Prediction is successfull
#
#
#
# X test value :  [23. 35. 96.  4.]
# Predicted value :  1
# Real test value:   4
# Prediction is unsuccessfull
#
#
#
# X test value :  [70. 50. 67. 22.]
# Predicted value :  3
# Real test value:   2
# Prediction is unsuccessfull
#
#
#
# X test value :  [48. 49. 39.  5.]
# Predicted value :  1
# Real test value:   4
# Prediction is unsuccessfull
#
#
#
# X test value :  [60. 53. 93. 28.]
# Predicted value :  3
# Real test value:   3
# Prediction is successfull
#
#
#
# X test value :  [ 16.  54. 147.  29.]
# Predicted value :  3
# Real test value:   3
# Prediction is successfull
#
#
#
# X test value :  [47. 25. 21.  1.]
# Predicted value :  1
# Real test value:   3
# Prediction is unsuccessfull
#
#
#
# X test value :  [ 61.  46. 318.  18.]
# Predicted value :  3
# Real test value:   3
# Prediction is successfull
#
#
#
# X test value :  [ 48.  43. 110.  15.]
# Predicted value :  3
# Real test value:   2
# Prediction is unsuccessfull
#
#
#
# X test value :  [65. 45. 67. 13.]
# Predicted value :  2
# Real test value:   3
# Prediction is unsuccessfull
#
#
#
# X test value :  [  4.  47. 123.  11.]
# Predicted value :  1
# Real test value:   1
# Prediction is successfull
#
#
#
# X test value :  [ 9. 53. 50. 13.]
# Predicted value :  1
# Real test value:   1
# Prediction is successfull
#
#
#
# X test value :  [ 35.  43. 224.  17.]
# Predicted value :  3
# Real test value:   1
# Prediction is unsuccessfull
#
#
#
# X test value :  [65. 64. 88. 26.]
# Predicted value :  3
# Real test value:   4
# Prediction is unsuccessfull
#
#
#
# X test value :  [ 8. 24. 18.  0.]
# Predicted value :  1
# Real test value:   4
# Prediction is unsuccessfull
#
#
#
# X test value :  [35. 40. 49. 20.]
# Predicted value :  1
# Real test value:   1
# Prediction is successfull
#
#
#
# X test value :  [ 71.  67. 110.  23.]
# Predicted value :  3
# Real test value:   3
# Prediction is successfull
#
#
#
# X test value :  [33. 36. 41. 10.]
# Predicted value :  1
# Real test value:   1
# Prediction is successfull
#
#
#
# X test value :  [ 61.  50. 102.   9.]
# Predicted value :  2
# Real test value:   2
# Prediction is successfull
#
#
#
# X test value :  [ 9. 21. 17.  2.]
# Predicted value :  1
# Real test value:   1
# Prediction is successfull
#
#
#
# X test value :  [33. 30. 22.  0.]
# Predicted value :  1
# Real test value:   3
# Prediction is unsuccessfull
#
#
# ----------------------------------
#
#       Accuracy value: 40.0
#
# ----------------------------------
